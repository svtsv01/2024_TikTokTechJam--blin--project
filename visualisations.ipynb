# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('./Data/blin_dataset.tsv', sep = '\t', index_col=0)

# %%
sns.countplot(df, x = 'label')
# Out:
# <Axes: xlabel='label', ylabel='count'>
